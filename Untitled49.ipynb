# %% [markdown]
# <a href="https://colab.research.google.com/github/Chico123-wq/Battery_MS2/blob/main/Untitled49.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Battery pipeline ready")
# Out:
# Battery pipeline ready
